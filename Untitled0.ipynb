# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjali-rajput8076/Hello-World/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple conditional and loop
number = 10

if number % 2 == 0:
    print("Even Number")
# Out:
# Even Number

# %% [markdown]
# # New Section
